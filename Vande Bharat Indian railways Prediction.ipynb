# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Name : Bishwajit Sen
#
# project : Vande Bharat, Indian Railways Prediction

# %% [markdown]
# # Vande Bharat, Indian Railways Prediction

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Importing Data

# %%
df = pd.read_csv(r"C:\Users\Dell\OneDrive\Desktop\PRACTICE\vande\archive (5)\Vande Bharat.csv")
df.head()
# Out:
#    Sr. No.                                         Train Name Train Number  \
# 0        1          New Delhi - Varanasi Vande Bharat Express  22435/22436
# 1        2  New Delhi - Shri Mata Vaishno Devi Katra Vande...  22439/22440
# 2        3  Mumbai Central - Gandhinagar Capital Vande Bha...  20901/20902
# 3        4       New Delhi - Amb Andaura Vande Bharat Express  22447/22448
# 4        5  MGR Chennai Central - Mysuru Vande Bharat Express  20607/20608
#
#   Originating City Originating Station Terminal City  \
# 0            Delhi           New Delhi      Varanasi
# 1            Delhi           New Delhi         Katra
# 2           Mumbai      Mumbai Central   Gandhinagar
# 3            Delhi           New Delhi       Andaura
# 4          Chennai     Chennai Central        Mysuru
#
#                Terminal Station Operator  No. of Cars          Frequency  \
# 0             Varanasi Junction       NR           16   Except Thursdays
# ...

# %%
df
# Out:
#     Sr. No.                                         Train Name Train Number  \
# 0         1          New Delhi - Varanasi Vande Bharat Express  22435/22436
# 1         2  New Delhi - Shri Mata Vaishno Devi Katra Vande...  22439/22440
# 2         3  Mumbai Central - Gandhinagar Capital Vande Bha...  20901/20902
# 3         4       New Delhi - Amb Andaura Vande Bharat Express  22447/22448
# 4         5  MGR Chennai Central - Mysuru Vande Bharat Express  20607/20608
# 5         6             Bilaspur - Nagpur Vande Bharat Express  20825/20826
# 6         7       Howrah - New Jalpaiguri Vande Bharat Express  22301/22302
# 7         8  Visakhapatnam - Secunderabad Vande Bharat Express  20833/20834
# 8         9         Mumbai CSMT - Solapur Vande Bharat Express  22225/22226
# 9        10  Mumbai CSMT - Sainagar Shirdi Vande Bharat Exp...  22223/22224
# 10       11  Rani Kamalapati (Habibganj) - Hazrat Nizamuddi...  20171/20172
# ...

# %%
df1 = df[["Train Name","Originating City","Terminal City","Operator","Speed","Inauguration"]]
df1.head()
# Out:
#                                           Train Name Originating City  \
# 0          New Delhi - Varanasi Vande Bharat Express            Delhi
# 1  New Delhi - Shri Mata Vaishno Devi Katra Vande...            Delhi
# 2  Mumbai Central - Gandhinagar Capital Vande Bha...           Mumbai
# 3       New Delhi - Amb Andaura Vande Bharat Express            Delhi
# 4  MGR Chennai Central - Mysuru Vande Bharat Express          Chennai
#
#   Terminal City Operator              Speed Inauguration
# 0      Varanasi       NR  130 km/h (81 mph)    2/15/2019
# 1         Katra       NR  130 km/h (81 mph)    10/3/2019
# 2   Gandhinagar       WR  130 km/h (81 mph)    9/30/2022
# 3       Andaura       NR  130 km/h (81 mph)   10/13/2022
# 4        Mysuru       SR  130 km/h (81 mph)   11/11/2022

# %% [markdown]
# Extracting Inauguration Year from Inauguration Date

# %%
df['Year'] = pd.DatetimeIndex(df['Inauguration']).year
df
# Out:
#     Sr. No.                                         Train Name Train Number  \
# 0         1          New Delhi - Varanasi Vande Bharat Express  22435/22436
# 1         2  New Delhi - Shri Mata Vaishno Devi Katra Vande...  22439/22440
# 2         3  Mumbai Central - Gandhinagar Capital Vande Bha...  20901/20902
# 3         4       New Delhi - Amb Andaura Vande Bharat Express  22447/22448
# 4         5  MGR Chennai Central - Mysuru Vande Bharat Express  20607/20608
# 5         6             Bilaspur - Nagpur Vande Bharat Express  20825/20826
# 6         7       Howrah - New Jalpaiguri Vande Bharat Express  22301/22302
# 7         8  Visakhapatnam - Secunderabad Vande Bharat Express  20833/20834
# 8         9         Mumbai CSMT - Solapur Vande Bharat Express  22225/22226
# 9        10  Mumbai CSMT - Sainagar Shirdi Vande Bharat Exp...  22223/22224
# 10       11  Rani Kamalapati (Habibganj) - Hazrat Nizamuddi...  20171/20172
# ...

# %% [markdown]
# Information about this dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sr. No.              26 non-null     int64
#  1   Train Name           26 non-null     object
#  2   Train Number         26 non-null     object
#  3   Originating City     26 non-null     object
#  4   Originating Station  26 non-null     object
#  5   Terminal City        26 non-null     object
#  6   Terminal Station     26 non-null     object
#  7   Operator             26 non-null     object
#  8   No. of Cars          26 non-null     int64
#  9   Frequency            26 non-null     object
#  10  Distance             26 non-null     object
#  11  Travel Time          26 non-null     object
#  12  Speed                26 non-null     object
#  13  Average Speed        26 non-null     object
#  14  Inauguration         26 non-null     object
# ...

# %% [markdown]
# Vande Bharat Express - Inauguration Year

# %%
sns.countplot(x='Year',data=df)
plt.title("Inauguration Year")
plt.xlabel("Year")
plt.ylabel("Train Counts")
plt.show()

# %% [markdown]
# 18 Vande Bharat Express has been inaugurated in the year 2023 (till date)

# %% [markdown]
# 5 Vande Bharat Express had been inaugurated in the year 2022

# %% [markdown]
# 2 Vande Bharat Express had been inaugurated in the year 2019

# %% [markdown]
# Different Operating Zones

# %%
sns.countplot(x='Operator',data=df)
plt.title("Opearting Zones")
plt.xlabel("Zone")
plt.ylabel("Train Counts")
plt.show()

# %% [markdown]
# NR Zone and CR Zone - Opearting maximum VB compared to others

# %% [markdown]
# Vande Bharat Express count Zone wise

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(df,x='Operator', y='Train Name')
plt.xticks(rotation=90, ha='right')
plt.title('Vande Bharat (Zone wise)')
plt.show()

# %% [markdown]
# Vande Bharat Express - Terminal Cities

# %%
sns.countplot(y='Terminal City',data=df)
plt.title("Terminating point city wise")
plt.ylabel("Terminal City")
plt.xlabel("Trains")
plt.show()

# %% [markdown]
# 2 VB terminates at Madgaon

# %% [markdown]
# Vande Bharat Express - Source/Originating Station

# %%
sns.countplot(y='Originating City',data=df)
plt.title("Staring point city wise")
plt.ylabel("Originating City")
plt.xlabel("Trains")
plt.show()

# %% [markdown]
# 5 VB originates from Delhi and Mumbai respectively

# %% [markdown]
# Originating Cities - Zone wise

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(df,x='Operator', y='Originating City')
plt.xticks(rotation=90, ha='right')
plt.title('Originating City (Zone wise)')
plt.show()

# %% [markdown]
# NR Zone has highest originating city

# %% [markdown]
# Terminating Cities - Zone wise

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(df,x='Operator', y='Terminal City')
plt.xticks(rotation=90, ha='right')
plt.title('Terminal City (Zone wise)')
plt.show()

# %% [markdown]
# NR Zone has highest terminating cities

# %%
df[['Originating City','Terminal City','Operator','Speed']].groupby(['Originating City','Terminal City','Operator','Speed']).size()
# Out:
# Originating City        Terminal City       Operator  Speed
# Bangalore               Hubbali - Dharwad   SWR       130 km/h (81 mph)    1
# Bhopal                  Delhi               WCR       160 km/h (99 mph)    1
#                         Jabalpur            WCR       110 km/h (68 mph)    1
# Bilaspur, Chhattisgarh  Nagpur              SECR      130 km/h (81 mph)    1
# Chennai                 Coimbatore          SR        130 km/h (81 mph)    1
#                         Mysuru              SR        130 km/h (81 mph)    1
# Delhi                   Ajmer               NWR       110 km/h (68 mph)    1
#                         Andaura             NR        130 km/h (81 mph)    1
#                         Dehradun            NR        130 km/h (81 mph)    1
#                         Katra               NR        130 km/h (81 mph)    1
#                         Varanasi            NR        130 km/h (81 mph)    1
# ...

# %% [markdown]
# VB originates from Delhi has highest terminal cities (5)

# %% [markdown]
# VB originates from Mumbai has Second highest terminal cities (4)

# %% [markdown]
# Average occupancy of Vande Bharat Express - Zone wise

# %%
sns.scatterplot(df,x='Average occupancy', y='Operator')
plt.xticks(rotation=90, ha='right')
plt.title('Average Occupancy (Zone wise)')
plt.show()

# %% [markdown]
# SR Zone has highest occupancy

# %% [markdown]
# Vande Bharat Express speed - Zone wise

# %%
sns.scatterplot(df,x='Operator', y='Speed')
plt.xticks(rotation=45, ha='right')
plt.title('VB Speed (Zone wise)')
plt.show()

# %% [markdown]
# ande Bharat Express from WCR Zone has the highest operating speed - 160 Km/h

# %% [markdown]
# Vande Bharat Express Average Speed - Zone wise

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(df,x='Operator', y='Average Speed')
plt.xticks(rotation=90, ha='right')
plt.title('VB Average Speed (Zone wise)')
plt.show()

# %% [markdown]
# Vande Bharat Express from NR Zone has the highest avg speed - 95 Km/h

# %% [markdown]
# Vande Bharat Speeds

# %%
sns.scatterplot(df,y='Train Name', x='Speed')
plt.xticks(rotation=45, ha='right')
plt.title('VB Speeds')
plt.show()

# %% [markdown]
# Rani Kamalapati (Habibganj) - Hazrat Nizamuddin VB express has highest opearting speed - 160 Km/h

# %% [markdown]
# Vande Bharat Express - Distance vs Speed plot

# %%
sns.lineplot(data=df, x='Distance', y='Speed')
plt.xticks(rotation=45, ha='right')
plt.title('Distance vs Speed')
plt.show()

# %% [markdown]
# New Delhi - Varanasi Vande Bharat Express covers maximum distance compared to all Vande Bharat expresses present here

# %% [markdown]
# Distance covers - 759 Km;

# %% [markdown]
# Opearating speed - 130 Km/h;

# %% [markdown]
# Average Speed - 95 Km/h;

# %% [markdown]
# Operating Zone - NR;

# %% [markdown]
# # Number of Cars in Vande Bharat Express - Zone wise

# %%
plt.figure(figsize=(5,5))
sns.barplot(df,y='No. of Cars', x='Operator')
plt.xticks(rotation=90, ha='right')
plt.title('No of Cars in VB')
plt.show()

# %% [markdown]
# Vande Bharat operating in these zones are having highest number of cars - (16)

# %% [markdown]
# ER
#
# ECoR
#
# CR
#
# SCR
#
# SER

# %% [markdown]
# Vande Bharat Express - No of cars vs Opearting Speed

# %%
sns.scatterplot(data=df, y='No. of Cars', x='Speed')
plt.xticks(rotation=90, ha='right')
plt.title('No of Cars vs Opearting Speed')
plt.show()

# %% [markdown]
# Most of the VB has 16 cars

# %% [markdown]
# # Travel Time of VB (Zone wise)

# %%
plt.figure(figsize=(8, 8))
sns.lineplot(data=df, y='Travel Time', x='Operator')
plt.xticks(rotation=90, ha='right')
plt.title('Travel Time of VB (Zone wise)')
plt.show()

# %% [markdown]
# Vande Bharat from NER Zone takes least time to complete its journey

# %% [markdown]
# Travel Time of VB (Train wise)

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(data=df, x='Train Name', y='Travel Time')
plt.xticks(rotation=45, ha='right')
plt.title('Travel Time of VB (Train wise)')
plt.show()

# %%
df.describe()
# Out:
#          Sr. No.  No. of Cars         Year
# count  26.000000    26.000000    26.000000
# mean   13.230769    12.923077  2022.500000
# std     7.306478     3.969112     1.104536
# min     1.000000     8.000000  2019.000000
# 25%     7.250000     8.000000  2022.250000
# 50%    13.500000    16.000000  2023.000000
# 75%    19.000000    16.000000  2023.000000
# max    25.000000    16.000000  2023.000000

# %%
df.count()
# Out:
# Sr. No.                26
# Train Name             26
# Train Number           26
# Originating City       26
# Originating Station    26
# Terminal City          26
# Terminal Station       26
# Operator               26
# No. of Cars            26
# Frequency              26
# Distance               26
# Travel Time            26
# Speed                  26
# Average Speed          26
# Inauguration           26
# Average occupancy      26
# Year                   26
# dtype: int64

# %%
summary_stats = df.describe()

# %% [markdown]
# # Exploratory Data Analysis

# %%
sns.histplot(data=df, x='No. of Cars', bins=10)
plt.title("Distribution of No. of Cars")
plt.show()

# %% [markdown]
# Categorical Data Analysis:

# %%
sns.countplot(data=df, x='Train Name')
plt.xticks(rotation=90)
plt.title("Train Name Frequencies")
plt.show()

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7280\913915466.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
plt.figure(figsize=(8, 6))
sns.pairplot(df[['No. of Cars', 'Frequency', 'Distance', 'Travel Time']])
plt.title("Pair Plot of Numerical Variables")
plt.show()

# %%
df['Inauguration'] = pd.to_datetime(df['Inauguration'])
df.set_index('Inauguration', inplace=True)

plt.figure(figsize=(10, 6))
plt.plot(df['Frequency'], label='Frequency')
plt.plot(df['Distance'], label='Distance')
plt.plot(df['Travel Time'], label='Travel Time')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Time Series Analysis')
plt.legend()
plt.show()

# %% [markdown]
# Visualize data

# %%
sns.heatmap(df.isna())
# Out:
# <Axes: ylabel='Inauguration'>

# %%
df.shape
# Out:
# (26, 16)

# %%
df.isna().sum()
# Out:
# Sr. No.                0
# Train Name             0
# Train Number           0
# Originating City       0
# Originating Station    0
# Terminal City          0
# Terminal Station       0
# Operator               0
# No. of Cars            0
# Frequency              0
# Distance               0
# Travel Time            0
# Speed                  0
# Average Speed          0
# Average occupancy      0
# Year                   0
# dtype: int64

# %%
av_s = df['Average Speed']
av_s_sorted = df.sort_values(by='Average Speed', ascending=False)

# %%
plt.hist(av_s,bins =40,edgecolor ='k')

plt.xlabel("Averege Speed")
plt.ylabel("Frequency")
plt.title('Histogram of Sorted Average Speeds')

plt.xlabel('Averege Speed', labelpad=15)
plt.xticks(rotation=90)

plt.gca().get_yaxis().set_visible(False)

# %%
train_speed_sort=df.sort_values(by='Speed', ascending=False)
sorted_top_speed=train_speed_sort["Speed"]
top_speed_train=df['Train Name']
top_speed_train=df['Average Speed']

# %%
# Sort data by 'Average Speed' in descending order
sorted_data = df.sort_values(by='Average Speed', ascending=False)

# Select the top speed train (first row)
top_speed_train = sorted_data.iloc[0]

# Print the required information
print("Top Speed Train Information:")
print("Train Name:", top_speed_train['Train Name'])
print("Train Speed:", top_speed_train['Speed'])
print("Average Speed:", top_speed_train['Average Speed'])
# Out:
# Top Speed Train Information:
# Train Name: New Delhi - Varanasi Vande Bharat Express
# Train Speed: 130 km/h (81 mph)
# Average Speed: 95 km/h (59 mph)

# %%
df.tail()
# Out:
#               Sr. No.                                         Train Name  \
# Inauguration
# 2023-06-27         21       KSR Bengaluru - Dharwad Vande Bharat Express
# 2023-06-27         22  Rani Kamalapati (Habibganj) - Jabalpur Vande B...
# 2023-06-27         23               Indore - Bhopal Vande Bharat Express
# 2023-07-07         24  Jodhpur - Sabarmati (Ahmedabad) Vande Bharat E...
# 2023-07-07         25  Gorakhpur - Lucknow Charbagh Vande Bharat Express
#
#              Train Number Originating City          Originating Station  \
# Inauguration
# 2023-06-27    20661/20662        Bangalore               Bangalore City
# 2023-06-27    20173/20174           Bhopal  Habibganj (Rani Kamalapati)
# 2023-06-27    20911/20912           Indore              Indore Junction
# 2023-07-07    12461/12462          Jodhpur             Jodhpur Junction
# 2023-07-07    22549/22550        Gorakhpur           Gorakhpur Junction
#
# ...
